# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('data/full.csv')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
sns.scatterplot(data=df.loc[df.pdays < 999], x='pdays', y='campaign', hue='y', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='campaign'>

# %%
sns.scatterplot(data=df.loc[df.pdays < 999], x='previous', y='campaign', hue='y', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='previous', ylabel='campaign'>

# %%
df['concatct_var'] = df.campaign - df.previous

# %%
df.rename(columns={'concatct_var': 'contact_var'}, inplace=True)

# %%
sns.scatterplot(data=df.loc[df.pdays < 999], x='pdays', y='contact_var', hue='y', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='contact_var'>

# %%
df.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
# contact_var     0.000234 -0.073215  0.984927  0.153013 -0.250379
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  \
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# ...

# %%
df.loc[df.education == 'basic.4y',['job', 'education', 'contact_var']].groupby(['job']).mean()
# Out:
#                contact_var
# job
# admin.            2.116883
# blue-collar       2.507334
# entrepreneur      2.540146
# housemaid         2.643460
# management        3.070000
# retired           1.968174
# self-employed     2.655914
# services          2.484848
# student           1.461538
# technician        1.637931
# unemployed        2.910714
# unknown           2.961538

# %%
education_values = df.education.unique()
contact_var_df = pd.DataFrame()

print(education_values)

for name in education_values:
  if contact_var_df.empty:
    contact_var_df = df.loc[df.education == name, ['job', 'education', 'contact_var']].groupby(['job']).mean().rename(columns={'contact_var': name})
    print(contact_var_df)
  else:
    print(df.loc[df.education == name, ['job', 'education', 'contact_var']].groupby(['job']).mean().rename(columns={'contact_var': name}))
    contact_var_df = contact_var_df.join(df.loc[df.education == name, ['job', 'education', 'contact_var']].groupby(['job']).mean().rename(columns={'contact_var': name}))
# Out:
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
#                basic.4y
# job
# admin.         2.116883
# blue-collar    2.507334
# entrepreneur   2.540146
# housemaid      2.643460
# management     3.070000
# retired        1.968174
# self-employed  2.655914
# services       2.484848
# student        1.461538
# technician     1.637931
# unemployed     2.910714
# unknown        2.961538
#                high.school
# job
# admin.            2.414239
# blue-collar       2.291572
# entrepreneur      2.363248
# housemaid         2.597701
# management        2.231544
# retired           2.329710
# self-employed     2.508475
# services          2.443326
# student           1.521008
# technician        2.568156
# unemployed        2.281853
# unknown           2.270270
#                basic.6y
# job
# admin.         2.549669
# blue-collar    2.395512
# entrepreneur   2.507042
# housemaid      2.636364
# ...

# %%
contact_var_df
# Out:
#                basic.4y  high.school  basic.6y  basic.9y  professional.course  \
# job
# admin.         2.116883     2.414239  2.549669  2.767535             2.154270
# blue-collar    2.507334     2.291572  2.395512  2.385316             2.708609
# entrepreneur   2.540146     2.363248  2.507042  2.295238             2.496296
# housemaid      2.643460     2.597701  2.636364  2.244681             1.898305
# management     3.070000     2.231544  2.317647  2.325301             2.123596
# retired        1.968174     2.329710  2.253333  2.827586             2.224066
# self-employed  2.655914     2.508475  3.200000  2.490909             2.922619
# services       2.484848     2.443326  2.367257  2.260309             2.582569
# student        1.461538     1.521008  0.692308  1.484848             1.348837
# technician     1.637931     2.568156  3.045977  2.250000             2.429518
# unemployed     2.910714     2.281853  2.000000  2.381720             2.260563
# ...

# %%
sns.heatmap(contact_var_df.corr())
# Out:
# <AxesSubplot:>

# %%
def get_age_canadian_classif(x):
  if not type(x) == int or type(x) == float:
    return 'none'
  else:
    if x in range(25, 65):
      return 'adult'
    elif x in range(15, 25):
      return 'youth'
    elif x > 64:
      return 'senior'

# %%
df.age.apply(get_age_canadian_classif)
# Out:
# 0         adult
# 1         adult
# 2         adult
# 3         adult
# 4         adult
#           ...
# 41183    senior
# 41184     adult
# 41185     adult
# 41186     adult
# 41187    senior
# Name: age, Length: 41188, dtype: object

# %%
df['age_can_clasif'] = df.age.apply(get_age_canadian_classif)

# %%
df.age_can_clasif.unique()
# Out:
# array(['adult', 'youth', 'senior'], dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'contact_var',
#        'age_can_clasif'],
#       dtype='object')
